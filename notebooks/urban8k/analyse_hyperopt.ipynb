# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os
import yaml

# %%
hopt_dir = './results/hyperopt_run_0001/'

all_results = []

for runnum in range(len(os.listdir(hopt_dir))):
    runname = 'run_%06d' % runnum
    loadpath = hopt_dir + runname + '/best_and_final.yaml'
    
    if not os.path.exists(loadpath):
        continue
        
    all_results.append(yaml.load(open(loadpath)))

print all_results[-1]
# Out:
# {'best_val_acc': 0.7131313131313132, 'final_val_loss': 0.9679490012786118, 'best_val_loss': 0.8653984902907284, 'final_val_acc': 0.7434343434343434}

# %%
best_acc = [res['best_val_acc'] for res in all_results]
final_acc = [res['final_val_acc'] for res in all_results]
best_loss = [res['best_val_loss'] for res in all_results]
final_loss = [res['final_val_loss'] for res in all_results]

# %%
plt.boxplot([best_acc, final_acc], 0, '+r', 0);
plt.plot([0.75, 0.75], [1, 2])

# %%
plt.plot(best_acc, 'b')
plt.plot(final_acc, 'g');
plt.ylim(0.5, 0.8)
# Out:
# (0.5, 0.8)

# %%
plt.plot(best_loss, 'b')
plt.plot(final_loss, 'g');
np.argmax(best_acc)
# Out:
# 94

# %%
plt.plot(best_loss, best_acc, '.')
