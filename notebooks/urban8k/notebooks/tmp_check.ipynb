# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import os
import numpy as np
import cPickle as pickle

import sys, os
sys.path.append(os.path.expanduser('~/projects/engaged_hackathon/'))
from engaged.features import frequency
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tmp = pickle.load(open('../tmp.pkl'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-b84db21187c7> in <module>()
#       1
#       2 tmp = pickle.load(open('../tmp.pkl'))
# ----> 3 print tmp[0]
#
# KeyError: 0

# %%
for xx in tmp['train_X'][:10]:
    plt.figure()
    plt.plot(xx.ravel())
#     plt.imshow(xx[0, :, :])
