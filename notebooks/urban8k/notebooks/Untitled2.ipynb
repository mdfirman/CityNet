# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import skimage.io

# %%
I = '/home/michael/projects/shape_sharing/data/cleaned_3D/renders_no_walls/1_kitchen_0004_1/depth.png'
im = skimage.io.imread(I)

# %%
plt.imshow(im == 2**16-1)
plt.colorbar()
print im.max()
print 2**16
# Out:
# 65535
# 65536
