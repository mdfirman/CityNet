# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import csv
import os
import sys
import numpy as np
import collections
import scipy.io
from time import time

# CNN bits
import theano
import theano.tensor as T
import lasagne

# hyperopt bits
import hyperopt
from hyperopt import hp, fmin, tpe, STATUS_OK, STATUS_FAIL

# for evaluation
sys.path.append(os.path.expanduser('~/projects/engaged_hackathon/'))
from engaged.features import evaluation
from sklearn import metrics
from sklearn.metrics import roc_curve, auc

import lasagne_helpers
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Data input

# %%
datapath = '/home/michael/projects/engaged_hackathon_data/detection/train_test_patches/'

X_train, y_train, X_val, y_val, X_test, y_test = \
    lasagne_helpers.load_dataset(datapath + 'small.mat')

# %%
print X_train.shape
print X_val.shape
print X_test.shape
# Out:
# (2800, 1, 75, 19)
# (1200, 1, 75, 19)
# (2000, 1, 75, 19)

# %%
from math import log
space = (
    hp.uniform( 'drop_input', 0.0, 0.5),
    hp.quniform( 'conv_depth', 1, 1, 1),
    hp.quniform('num_filters1', 32, 128, 1 ),
    hp.quniform('num_filters2', 32, 128, 1 ),
    hp.quniform( 'pool_size', 2, 5, 1 ),
    hp.quniform( 'dense_depth', 1, 4, 1),
    hp.quniform( 'dense_width', 500, 1000, 1),
    hp.uniform( 'drop_dense_hidden', 0.2, 0.8), 
    hp.quniform('log2_minibatch_size', 4, 10, 1 ),
    hp.uniform( 'learning_rate',  0.01 ,  0.1 ), #0.01 - 0.1
    hp.uniform( 'momentum', 0.9, 0.999), #0.9 - 1
#     hp.loguniform( 'learning_rate', log( 0.01 ), log( 0.1 )), #0.01 - 0.1
#     hp.loguniform( 'momentum', log(0.9), log(0.999)), #0.9 - 1
)

# %%
print 2**np.array([4, 5,6 ,7, 8, 9, 10])
# Out:
# [  16   32   64  128  256  512 1024]

# %%
num_epochs = 15

def run_test( params ):

    """
    
    """
    # extract parameters
    drop_input, conv_depth, num_filters1, num_filters2, pool_size, dense_depth, \
        dense_width, drop_dense_hidden, log2_minibatch_size, learning_rate, momentum = params
    
    minibatch_size = int(2**log2_minibatch_size)
    
    input_var = T.tensor4('inputs')
    target_var = T.ivector('targets')

        # create the network
    network = lasagne_helpers.build_cnn(input_var,
        im_width=X_train.shape[2],
        im_height=X_train.shape[3],
        drop_input=drop_input,
        conv_depth=conv_depth,
        num_filters1=num_filters1, 
        num_filters2=num_filters2, 
        pool_size=pool_size, 
        dense_depth=dense_depth,
        dense_width=dense_width, 
        drop_dense_hidden=drop_dense_hidden)

    
    # 
    # Create a loss expression for training, i.e., a scalar objective we want
    # to minimize (for our multi-class problem, it is the cross-entropy loss):
    prediction = lasagne.layers.get_output(network)
    loss = lasagne.objectives.categorical_crossentropy(prediction, target_var)
    loss = loss.mean()
    # We could add some weight decay as well here, see lasagne.regularization.

    # Create update expressions for training, i.e., how to modify the
    # parameters at each training step. Here, we'll use Stochastic Gradient
    # Descent (SGD) with Nesterov momentum, but Lasagne offers plenty more.
    params = lasagne.layers.get_all_params(network, trainable=True)
    updates = lasagne.updates.nesterov_momentum(
            loss, params, learning_rate=learning_rate, momentum=learning_rate)

    # Create a loss expression for validation/testing. The crucial difference
    # here is that we do a deterministic forward pass through the network,
    # disabling dropout layers.
    test_prediction = lasagne.layers.get_output(network, deterministic=True)
    test_loss = lasagne.objectives.categorical_crossentropy(test_prediction,
                                                            target_var)
    test_loss = test_loss.mean()
    # As a bonus, also create an expression for the classification accuracy:
    test_acc = T.mean(T.eq(T.argmax(test_prediction, axis=1), target_var),
                      dtype=theano.config.floatX)

    # Compile a function performing a training step on a mini-batch (by giving
    # the updates dictionary) and returning the corresponding training loss:
    train_fn = theano.function([input_var, target_var], loss, updates=updates)

    # Compile a second function computing the validation loss and accuracy:
    val_fn = theano.function([input_var, target_var], [test_loss, test_acc])

    test_prediction = lasagne.layers.get_output(network, deterministic=True)
    predict_fn = theano.function([input_var], T.argmax(test_prediction, axis=1))
    
    # Finally, launch the training loop.
    
#     print "  epoch    train loss    valid loss    train/val    valid acc  dur"
    
    # We iterate over epochs:
    for epoch in range(num_epochs):
        # In each epoch, we do a full pass over the training data:
        train_err = 0
        train_batches = 0
        start_time = time()
        for count, batch in enumerate(lasagne_helpers.iterate_balanced_minibatches(X_train, y_train, int(minibatch_size))):
            print "Batch %d " % count,
            sys.stdout.flush()
            inputs, targets = batch
            train_err += train_fn(inputs, targets)
            train_batches += 1

        # And a full pass over the validation data:
        val_err = 0
        val_acc = 0
        val_batches = 0
        y_preds, y_gts = [], []
        for batch in lasagne_helpers.iterate_balanced_minibatches(
                X_val, y_val, int(minibatch_size)):
            
            inputs, targets = batch
            err, acc = val_fn(inputs, targets)
            val_err += err
            val_acc += acc
            val_batches += 1
            
            y_preds.append( predict_fn(inputs))
            y_gts.append(targets)
            
        norm_acc = lasagne_helpers.normalised_accuracy(
            np.hstack(y_gts), np.hstack(y_preds))

        # Then we print the results for this epoch:
        print("Epoch {} of {} took {:.3f}s".format(
            epoch + 1, num_epochs, time() - start_time))
        print("  training loss:\t\t{:.6f}".format(train_err / train_batches))
        print("  validation loss:\t\t{:.6f}".format(val_err / val_batches))
        print("  validation accuracy:\t\t{:.2f} %".format(
            val_acc / val_batches * 100))
        print("  normalised val acc:\t\t{:.2f} %".format(
            norm_acc))
        sys.stdout.flush()
              
    return norm_acc

# %%
# headers = [ 'test_accuracy', 'hidden_units', 'learning_rate', 'momentum', 'patience', 'filter1', 'filter2', 'batch_size', 'drop_out', 'epochs', 'conv_1', 'conv_2']

run_counter = 0
def run_wrapper( params ):
    """
    This is the wrappper which writes params to file, and which is minimised"""
    global run_counter
    global o_f

    run_counter += 1
    print "run", run_counter
    sys.stdout.flush()
    #print "params: {}s\n".format(str(params))

    s = time()
#     normalised_accuracy = run_test( params )
    try:
        normalised_accuracy = run_test( params )
        print "normalised_accuracy:", normalised_accuracy
        print "elapsed: {}s \n".format( int( round( time() - s )))
        writer.writerow( [ normalised_accuracy ] + list( params ))
        o_f.flush()
        return {'loss': -normalised_accuracy,
               'status': STATUS_OK}
    except Exception as e:
        print "FAILURE", str(e)
        print "elapsed: {}s \n".format( int( round( time() - s )))
        writer.writerow( [ 'FAILURE' ] + list( params ))
        o_f.flush()
        return {'loss': np.inf,
                'status': STATUS_FAIL,
                'exception': str(e)
               }

output_file = 'hyperopt_log.csv'
max_evals = 250

headers = [ 'norm_acc', 'drop_input', 'conv_depth',
           'num_filters1', 'num_filters2', 'pool_size', 'dense_depth', 
        'dense_width', 'drop_dense_hidden', 'log2_minibatch_size', 'learning_rate', 
           'momentum', 'hidden_units2', 'learning_rate', 'momentum', 'epochs']

o_f = open( output_file, 'wb' )
writer = csv.writer( o_f )
writer.writerow( headers )
o_f.flush()

start_time = time()
best = fmin( run_wrapper, space, algo = tpe.suggest, max_evals = max_evals )
end_time = time()

print "Seconds passed:", int( round( end_time - start_time ))
print "Best run:"
# , optimizer.get_best_run()
print best
print run_test( hyperopt.space_eval( space, best ))
# Out:
#  run 1
# 0.490382099192 1.0 4.0
# 75 19
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 1 of 15 took 82.337s
#   training loss:		0.702518
#   validation loss:		0.685881
#   validation accuracy:		50.00 %
#   normalised val acc:		0.50 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 2 of 15 took 82.301s
#   training loss:		0.690483
#   validation loss:		0.677601
#   validation accuracy:		56.35 %
#   normalised val acc:		0.56 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 3 of 15 took 82.451s
#   training loss:		0.675025
#   validation loss:		0.672629
#   validation accuracy:		67.19 %
#   normalised val acc:		0.67 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 4 of 15 took 81.479s
#   training loss:		0.671130
#   validation loss:		0.667622
#   validation accuracy:		66.80 %
#   normalised val acc:		0.67 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 5 of 15 took 81.475s
#   training loss:		0.662319
#   validation loss:		0.664005
#   validation accuracy:		65.92 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 6 of 15 took 81.668s
#   training loss:		0.655008
#   validation loss:		0.658100
#   validation accuracy:		65.92 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 7 of 15 took 82.181s
#   training loss:		0.652275
#   validation loss:		0.656598
#   validation accuracy:		64.06 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 8 of 15 took 80.860s
#   training loss:		0.648588
#   validation loss:		0.654910
#   validation accuracy:		63.57 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 9 of 15 took 80.756s
#   training loss:		0.644827
#   validation loss:		0.650987
#   validation accuracy:		62.89 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 10 of 15 took 81.313s
#   training loss:		0.640923
#   validation loss:		0.649718
#   validation accuracy:		63.38 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 11 of 15 took 80.923s
#   training loss:		0.640252
#   validation loss:		0.647768
#   validation accuracy:		62.50 %
#   normalised val acc:		0.62 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 12 of 15 took 80.968s
#   training loss:		0.632071
#   validation loss:		0.646308
#   validation accuracy:		62.60 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 13 of 15 took 81.263s
#   training loss:		0.637092
#   validation loss:		0.643920
#   validation accuracy:		62.30 %
#   normalised val acc:		0.62 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 14 of 15 took 80.741s
#   training loss:		0.625967
#   validation loss:		0.645607
#   validation accuracy:		61.72 %
#   normalised val acc:		0.62 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 15 of 15 took 80.851s
#   training loss:		0.632972
#   validation loss:		0.645474
#   validation accuracy:		61.72 %
#   normalised val acc:		0.62 %
# normalised_accuracy: 0.6171875
# elapsed: 1224s
#
# run 2
# 0.333981204704 1.0 2.0
# 75 19
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 1 of 15 took 123.662s
#   training loss:		0.680792
#   validation loss:		0.679748
#   validation accuracy:		65.71 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 2 of 15 took 123.690s
#   training loss:		0.667803
#   validation loss:		0.671518
#   validation accuracy:		62.76 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 3 of 15 took 123.673s
#   training loss:		0.658237
#   validation loss:		0.665369
#   validation accuracy:		61.72 %
#   normalised val acc:		0.62 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 4 of 15 took 123.675s
#   training loss:		0.654548
#   validation loss:		0.659485
#   validation accuracy:		61.46 %
#   normalised val acc:		0.61 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 5 of 15 took 123.642s
#   training loss:		0.644107
#   validation loss:		0.651633
#   validation accuracy:		61.55 %
#   normalised val acc:		0.62 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 6 of 15 took 123.548s
#   training loss:		0.638882
#   validation loss:		0.647831
#   validation accuracy:		61.72 %
#   normalised val acc:		0.62 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 7 of 15 took 123.983s
#   training loss:		0.628502
#   validation loss:		0.632514
#   validation accuracy:		63.80 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 8 of 15 took 123.633s
#   training loss:		0.620124
#   validation loss:		0.624992
#   validation accuracy:		64.84 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 9 of 15 took 124.530s
#   training loss:		0.610125
#   validation loss:		0.612300
#   validation accuracy:		65.54 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 10 of 15 took 125.029s
#   training loss:		0.604149
#   validation loss:		0.595315
#   validation accuracy:		68.23 %
#   normalised val acc:		0.68 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 11 of 15 took 124.540s
#   training loss:		0.591559
#   validation loss:		0.594628
#   validation accuracy:		67.80 %
#   normalised val acc:		0.68 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 12 of 15 took 123.865s
#   training loss:		0.582222
#   validation loss:		0.576469
#   validation accuracy:		69.01 %
#   normalised val acc:		0.69 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 13 of 15 took 123.734s
#   training loss:		0.567346
#   validation loss:		0.567059
#   validation accuracy:		69.62 %
#   normalised val acc:		0.70 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 14 of 15 took 124.227s
#   training loss:		0.556421
#   validation loss:		0.550292
#   validation accuracy:		70.92 %
#   normalised val acc:		0.71 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  (1152,) (1152,)
# Epoch 15 of 15 took 123.636s
#   training loss:		0.554509
#   validation loss:		0.556558
#   validation accuracy:		70.05 %
#   normalised val acc:		0.70 %
# normalised_accuracy: 0.700520833333
# elapsed: 1862s
#
# run 3
# 0.25334305547 1.0 4.0
# 75 19
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 1 of 15 took 45.088s
#   training loss:		0.652192
#   validation loss:		0.632558
#   validation accuracy:		65.80 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 2 of 15 took 45.188s
#   training loss:		0.609273
#   validation loss:		0.598267
#   validation accuracy:		68.32 %
#   normalised val acc:		0.68 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 3 of 15 took 45.107s
#   training loss:		0.575539
#   validation loss:		0.549870
#   validation accuracy:		71.96 %
#   normalised val acc:		0.72 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 4 of 15 took 45.405s
#   training loss:		0.540428
#   validation loss:		0.522463
#   validation accuracy:		72.92 %
#   normalised val acc:		0.73 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 5 of 15 took 45.162s
#   training loss:		0.531110
#   validation loss:		0.518626
#   validation accuracy:		74.31 %
#   normalised val acc:		0.74 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 6 of 15 took 45.215s
#   training loss:		0.525802
#   validation loss:		0.520318
#   validation accuracy:		72.83 %
#   normalised val acc:		0.73 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 7 of 15 took 45.352s
#   training loss:		0.518965
#   validation loss:		0.537130
#   validation accuracy:		71.09 %
#   normalised val acc:		0.71 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 8 of 15 took 45.859s
#   training loss:		0.508112
#   validation loss:		0.499453
#   validation accuracy:		76.04 %
#   normalised val acc:		0.76 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 9 of 15 took 45.703s
#   training loss:		0.510900
#   validation loss:		0.503160
#   validation accuracy:		75.87 %
#   normalised val acc:		0.76 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 10 of 15 took 45.671s
#   training loss:		0.509649
#   validation loss:		0.497474
#   validation accuracy:		76.39 %
#   normalised val acc:		0.76 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 11 of 15 took 45.828s
#   training loss:		0.505343
#   validation loss:		0.498819
#   validation accuracy:		76.13 %
#   normalised val acc:		0.76 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 12 of 15 took 45.814s
#   training loss:		0.511550
#   validation loss:		0.517968
#   validation accuracy:		73.78 %
#   normalised val acc:		0.74 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 13 of 15 took 45.814s
#   training loss:		0.505924
#   validation loss:		0.509965
#   validation accuracy:		74.05 %
#   normalised val acc:		0.74 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 14 of 15 took 45.547s
#   training loss:		0.499879
#   validation loss:		0.512990
#   validation accuracy:		74.05 %
#   normalised val acc:		0.74 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 15 of 15 took 45.521s
#   training loss:		0.515124
#   validation loss:		0.540264
#   validation accuracy:		72.83 %
#   normalised val acc:		0.73 %
# normalised_accuracy: 0.728298611111
# elapsed: 685s
#
# run 4
# 0.290022587101 1.0 2.0
# 75 19
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 1 of 15 took 42.905s
#   training loss:		0.685979
#   validation loss:		0.684676
#   validation accuracy:		55.27 %
#   normalised val acc:		0.55 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 2 of 15 took 42.899s
#   training loss:		0.680654
#   validation loss:		0.681998
#   validation accuracy:		61.72 %
#   normalised val acc:		0.62 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 3 of 15 took 42.884s
#   training loss:		0.676483
#   validation loss:		0.679940
#   validation accuracy:		63.48 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 4 of 15 took 43.050s
#   training loss:		0.671009
#   validation loss:		0.675839
#   validation accuracy:		63.87 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 5 of 15 took 43.065s
#   training loss:		0.666509
#   validation loss:		0.670796
#   validation accuracy:		63.87 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 6 of 15 took 42.916s
#   training loss:		0.665254
#   validation loss:		0.671972
#   validation accuracy:		62.60 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 7 of 15 took 42.945s
#   training loss:		0.659780
#   validation loss:		0.665219
#   validation accuracy:		63.67 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 8 of 15 took 42.917s
#   training loss:		0.655143
#   validation loss:		0.662599
#   validation accuracy:		63.09 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 9 of 15 took 42.898s
#   training loss:		0.652702
#   validation loss:		0.655743
#   validation accuracy:		64.06 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 10 of 15 took 42.925s
#   training loss:		0.649202
#   validation loss:		0.658767
#   validation accuracy:		63.38 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 11 of 15 took 43.068s
#   training loss:		0.646569
#   validation loss:		0.655068
#   validation accuracy:		62.60 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 12 of 15 took 43.013s
#   training loss:		0.644361
#   validation loss:		0.651660
#   validation accuracy:		62.60 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 13 of 15 took 43.288s
#   training loss:		0.639841
#   validation loss:		0.652847
#   validation accuracy:		62.11 %
#   normalised val acc:		0.62 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 14 of 15 took 42.877s
#   training loss:		0.637486
#   validation loss:		0.650825
#   validation accuracy:		62.11 %
#   normalised val acc:		0.62 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 15 of 15 took 42.904s
#   training loss:		0.632416
#   validation loss:		0.642108
#   validation accuracy:		63.67 %
#   normalised val acc:		0.64 %
# normalised_accuracy: 0.63671875
# elapsed: 648s
#
# run 5
# 0.220697378547 1.0 4.0
# 75 19
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 1 of 15 took 28.488s
#   training loss:		0.695302
#   validation loss:		0.686075
#   validation accuracy:		52.83 %
#   normalised val acc:		0.53 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 2 of 15 took 28.511s
#   training loss:		0.681799
#   validation loss:		0.681220
#   validation accuracy:		55.66 %
#   normalised val acc:		0.56 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 3 of 15 took 28.448s
#   training loss:		0.675978
#   validation loss:		0.676125
#   validation accuracy:		59.38 %
#   normalised val acc:		0.59 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 4 of 15 took 28.542s
#   training loss:		0.676174
#   validation loss:		0.672287
#   validation accuracy:		64.75 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 5 of 15 took 28.633s
#   training loss:		0.670887
#   validation loss:		0.671397
#   validation accuracy:		67.58 %
#   normalised val acc:		0.68 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 6 of 15 took 28.432s
#   training loss:		0.667152
#   validation loss:		0.666727
#   validation accuracy:		66.89 %
#   normalised val acc:		0.67 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 7 of 15 took 28.485s
#   training loss:		0.661422
#   validation loss:		0.663593
#   validation accuracy:		65.82 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 8 of 15 took 28.497s
#   training loss:		0.651643
#   validation loss:		0.661327
#   validation accuracy:		65.82 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 9 of 15 took 28.460s
#   training loss:		0.651880
#   validation loss:		0.658462
#   validation accuracy:		65.43 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 10 of 15 took 28.577s
#   training loss:		0.646896
#   validation loss:		0.655385
#   validation accuracy:		65.62 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 11 of 15 took 28.506s
#   training loss:		0.647948
#   validation loss:		0.653479
#   validation accuracy:		65.82 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 12 of 15 took 28.514s
#   training loss:		0.643761
#   validation loss:		0.652399
#   validation accuracy:		64.45 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 13 of 15 took 28.443s
#   training loss:		0.639308
#   validation loss:		0.648795
#   validation accuracy:		65.14 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 14 of 15 took 28.484s
#   training loss:		0.637872
#   validation loss:		0.648097
#   validation accuracy:		64.16 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 15 of 15 took 28.495s
#   training loss:		0.637454
#   validation loss:		0.645997
#   validation accuracy:		64.06 %
#   normalised val acc:		0.64 %
# normalised_accuracy: 0.640625
# elapsed: 430s
#
# run 6
# 0.395299676011 1.0 5.0
# 75 19
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 1 of 15 took 29.135s
#   training loss:		0.652016
#   validation loss:		0.645772
#   validation accuracy:		62.85 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 2 of 15 took 29.212s
#   training loss:		0.622561
#   validation loss:		0.609421
#   validation accuracy:		66.49 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 3 of 15 took 29.091s
#   training loss:		0.599311
#   validation loss:		0.612165
#   validation accuracy:		65.80 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 4 of 15 took 29.102s
#   training loss:		0.576642
#   validation loss:		0.556257
#   validation accuracy:		71.61 %
#   normalised val acc:		0.72 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 5 of 15 took 29.139s
#   training loss:		0.557946
#   validation loss:		0.554408
#   validation accuracy:		69.53 %
#   normalised val acc:		0.70 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 6 of 15 took 29.122s
#   training loss:		0.546298
#   validation loss:		0.554152
#   validation accuracy:		69.36 %
#   normalised val acc:		0.69 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 7 of 15 took 29.094s
#   training loss:		0.539302
#   validation loss:		0.551357
#   validation accuracy:		69.62 %
#   normalised val acc:		0.70 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 8 of 15 took 29.240s
#   training loss:		0.528680
#   validation loss:		0.564303
#   validation accuracy:		68.92 %
#   normalised val acc:		0.69 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 9 of 15 took 29.097s
#   training loss:		0.518306
#   validation loss:		0.507152
#   validation accuracy:		72.92 %
#   normalised val acc:		0.73 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 10 of 15 took 29.085s
#   training loss:		0.521241
#   validation loss:		0.528284
#   validation accuracy:		71.44 %
#   normalised val acc:		0.71 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 11 of 15 took 29.113s
#   training loss:		0.514989
#   validation loss:		0.513330
#   validation accuracy:		72.83 %
#   normalised val acc:		0.73 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 12 of 15 took 29.122s
#   training loss:		0.517297
#   validation loss:		0.503309
#   validation accuracy:		74.39 %
#   normalised val acc:		0.74 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 13 of 15 took 29.140s
#   training loss:		0.515222
#   validation loss:		0.508843
#   validation accuracy:		73.18 %
#   normalised val acc:		0.73 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 14 of 15 took 29.182s
#   training loss:		0.512194
#   validation loss:		0.537735
#   validation accuracy:		71.27 %
#   normalised val acc:		0.71 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 15 of 15 took 29.302s
#   training loss:		0.513008
#   validation loss:		0.540243
#   validation accuracy:		70.75 %
#   normalised val acc:		0.71 %
# normalised_accuracy: 0.707465277778
# elapsed: 439s
#
# run 7
# 0.444494664827 1.0 4.0
# 75 19
# Batch 0  FAILURE list index out of range
# elapsed: 152s
#
# run 8
# 0.189922517072 1.0 2.0
# 75 19
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 1 of 15 took 90.107s
#   training loss:		0.684356
#   validation loss:		0.677924
#   validation accuracy:		67.68 %
#   normalised val acc:		0.68 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 2 of 15 took 90.262s
#   training loss:		0.667938
#   validation loss:		0.663047
#   validation accuracy:		64.65 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 3 of 15 took 90.268s
#   training loss:		0.652477
#   validation loss:		0.652696
#   validation accuracy:		63.18 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 4 of 15 took 90.090s
#   training loss:		0.635972
#   validation loss:		0.637968
#   validation accuracy:		66.11 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 5 of 15 took 90.557s
#   training loss:		0.623014
#   validation loss:		0.623076
#   validation accuracy:		66.31 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 6 of 15 took 90.167s
#   training loss:		0.607352
#   validation loss:		0.607398
#   validation accuracy:		66.50 %
#   normalised val acc:		0.67 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 7 of 15 took 90.088s
#   training loss:		0.584518
#   validation loss:		0.577868
#   validation accuracy:		69.24 %
#   normalised val acc:		0.69 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 8 of 15 took 90.057s
#   training loss:		0.566923
#   validation loss:		0.556049
#   validation accuracy:		71.29 %
#   normalised val acc:		0.71 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 9 of 15 took 90.119s
#   training loss:		0.547847
#   validation loss:		0.560661
#   validation accuracy:		73.54 %
#   normalised val acc:		0.74 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 10 of 15 took 90.097s
#   training loss:		0.564020
#   validation loss:		0.530748
#   validation accuracy:		74.51 %
#   normalised val acc:		0.75 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 11 of 15 took 90.187s
#   training loss:		0.541856
#   validation loss:		0.519193
#   validation accuracy:		74.32 %
#   normalised val acc:		0.74 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 12 of 15 took 90.101s
#   training loss:		0.515871
#   validation loss:		0.540198
#   validation accuracy:		71.19 %
#   normalised val acc:		0.71 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 13 of 15 took 90.526s
#   training loss:		0.538527
#   validation loss:		0.510838
#   validation accuracy:		74.22 %
#   normalised val acc:		0.74 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 14 of 15 took 90.186s
#   training loss:		0.508351
#   validation loss:		0.522539
#   validation accuracy:		72.17 %
#   normalised val acc:		0.72 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 15 of 15 took 90.091s
#   training loss:		0.500571
#   validation loss:		0.498148
#   validation accuracy:		75.59 %
#   normalised val acc:		0.76 %
# normalised_accuracy: 0.755859375
# elapsed: 1356s
#
# run 9
# 0.119733387986 1.0 4.0
# 75 19
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 1 of 15 took 183.408s
#   training loss:		0.696469
#   validation loss:		0.691846
#   validation accuracy:		48.93 %
#   normalised val acc:		0.49 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 2 of 15 took 183.903s
#   training loss:		0.694207
#   validation loss:		0.690189
#   validation accuracy:		50.00 %
#   normalised val acc:		0.50 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 3 of 15 took 184.682s
#   training loss:		0.690756
#   validation loss:		0.688098
#   validation accuracy:		50.68 %
#   normalised val acc:		0.51 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 4 of 15 took 185.054s
#   training loss:		0.687490
#   validation loss:		0.686562
#   validation accuracy:		52.25 %
#   normalised val acc:		0.52 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 5 of 15 took 185.173s
#   training loss:		0.687229
#   validation loss:		0.684725
#   validation accuracy:		53.81 %
#   normalised val acc:		0.54 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 6 of 15 took 185.881s
#   training loss:		0.683591
#   validation loss:		0.682828
#   validation accuracy:		56.93 %
#   normalised val acc:		0.57 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 7 of 15 took 186.225s
#   training loss:		0.681615
#   validation loss:		0.682094
#   validation accuracy:		58.59 %
#   normalised val acc:		0.59 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 8 of 15 took 186.624s
#   training loss:		0.680219
#   validation loss:		0.680086
#   validation accuracy:		61.91 %
#   normalised val acc:		0.62 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 9 of 15 took 190.187s
#   training loss:		0.678987
#   validation loss:		0.678864
#   validation accuracy:		64.55 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 10 of 15 took 186.378s
#   training loss:		0.673524
#   validation loss:		0.677711
#   validation accuracy:		65.43 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 11 of 15 took 187.348s
#   training loss:		0.673431
#   validation loss:		0.674679
#   validation accuracy:		67.38 %
#   normalised val acc:		0.67 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 12 of 15 took 187.741s
#   training loss:		0.672259
#   validation loss:		0.672710
#   validation accuracy:		68.07 %
#   normalised val acc:		0.68 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 13 of 15 took 188.552s
#   training loss:		0.669630
#   validation loss:		0.672191
#   validation accuracy:		67.87 %
#   normalised val acc:		0.68 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 14 of 15 took 187.395s
#   training loss:		0.667324
#   validation loss:		0.669467
#   validation accuracy:		67.97 %
#   normalised val acc:		0.68 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 15 of 15 took 189.401s
#   training loss:		0.664064
#   validation loss:		0.667884
#   validation accuracy:		66.99 %
#   normalised val acc:		0.67 %
# normalised_accuracy: 0.669921875
# elapsed: 2802s
#
# run 10
# 0.481060966879 1.0 4.0
# 75 19
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 1 of 15 took 209.269s
#   training loss:		0.694097
#   validation loss:		0.691505
#   validation accuracy:		49.71 %
#   normalised val acc:		0.50 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 2 of 15 took 209.099s
#   training loss:		0.690999
#   validation loss:		0.689835
#   validation accuracy:		49.80 %
#   normalised val acc:		0.50 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 3 of 15 took 208.178s
#   training loss:		0.687802
#   validation loss:		0.688321
#   validation accuracy:		50.29 %
#   normalised val acc:		0.50 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 4 of 15 took 208.313s
#   training loss:		0.685840
#   validation loss:		0.687178
#   validation accuracy:		53.22 %
#   normalised val acc:		0.53 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 5 of 15 took 210.228s
#   training loss:		0.683333
#   validation loss:		0.685858
#   validation accuracy:		56.74 %
#   normalised val acc:		0.57 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 6 of 15 took 210.334s
#   training loss:		0.681421
#   validation loss:		0.684111
#   validation accuracy:		60.74 %
#   normalised val acc:		0.61 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 7 of 15 took 214.001s
#   training loss:		0.679642
#   validation loss:		0.683158
#   validation accuracy:		64.75 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 8 of 15 took 221.083s
#   training loss:		0.678718
#   validation loss:		0.682213
#   validation accuracy:		66.70 %
#   normalised val acc:		0.67 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 9 of 15 took 221.297s
#   training loss:		0.674962
#   validation loss:		0.681234
#   validation accuracy:		67.77 %
#   normalised val acc:		0.68 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 10 of 15 took 213.080s
#   training loss:		0.676240
#   validation loss:		0.680127
#   validation accuracy:		66.11 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 11 of 15 took 215.722s
#   training loss:		0.671890
#   validation loss:		0.677902
#   validation accuracy:		65.14 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 12 of 15 took 213.549s
#   training loss:		0.670978
#   validation loss:		0.676573
#   validation accuracy:		65.82 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 13 of 15 took 215.146s
#   training loss:		0.669281
#   validation loss:		0.676497
#   validation accuracy:		64.36 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 14 of 15 took 214.229s
#   training loss:		0.667844
#   validation loss:		0.675416
#   validation accuracy:		64.65 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  (1024,) (1024,)
# Epoch 15 of 15 took 215.213s
#   training loss:		0.666429
#   validation loss:		0.673937
#   validation accuracy:		64.06 %
#   normalised val acc:		0.64 %
# normalised_accuracy: 0.640625
# elapsed: 3202s
#
# run 11
# 0.101281950932 1.0 3.0
# 75 19
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 1 of 15 took 29.858s
#   training loss:		0.685538
#   validation loss:		0.679804
#   validation accuracy:		64.55 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 2 of 15 took 29.889s
#   training loss:		0.668918
#   validation loss:		0.667980
#   validation accuracy:		65.53 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 3 of 15 took 29.960s
#   training loss:		0.654899
#   validation loss:		0.659014
#   validation accuracy:		63.57 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 4 of 15 took 29.835s
#   training loss:		0.642833
#   validation loss:		0.651487
#   validation accuracy:		63.87 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 5 of 15 took 29.934s
#   training loss:		0.630376
#   validation loss:		0.646675
#   validation accuracy:		63.38 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 6 of 15 took 29.824s
#   training loss:		0.625142
#   validation loss:		0.633999
#   validation accuracy:		63.18 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 7 of 15 took 29.784s
#   training loss:		0.610990
#   validation loss:		0.620764
#   validation accuracy:		65.14 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 8 of 15 took 29.772s
#   training loss:		0.602476
#   validation loss:		0.619754
#   validation accuracy:		65.53 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 9 of 15 took 29.759s
#   training loss:		0.586609
#   validation loss:		0.594636
#   validation accuracy:		68.55 %
#   normalised val acc:		0.69 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 10 of 15 took 29.832s
#   training loss:		0.578825
#   validation loss:		0.578297
#   validation accuracy:		69.73 %
#   normalised val acc:		0.70 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 11 of 15 took 29.781s
#   training loss:		0.562018
#   validation loss:		0.564922
#   validation accuracy:		70.90 %
#   normalised val acc:		0.71 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 12 of 15 took 29.815s
#   training loss:		0.549336
#   validation loss:		0.557346
#   validation accuracy:		71.00 %
#   normalised val acc:		0.71 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 13 of 15 took 29.651s
#   training loss:		0.541554
#   validation loss:		0.527091
#   validation accuracy:		74.02 %
#   normalised val acc:		0.74 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 14 of 15 took 29.901s
#   training loss:		0.537669
#   validation loss:		0.535436
#   validation accuracy:		72.46 %
#   normalised val acc:		0.72 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  (1024,) (1024,)
# Epoch 15 of 15 took 29.885s
#   training loss:		0.525346
#   validation loss:		0.517189
#   validation accuracy:		73.83 %
#   normalised val acc:		0.74 %
# normalised_accuracy: 0.73828125
# elapsed: 451s
#
# run 12
# 0.355835038702 1.0 4.0
# 75 19
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 1 of 15 took 190.194s
#   training loss:		0.687332
#   validation loss:		0.675732
#   validation accuracy:		62.50 %
#   normalised val acc:		0.62 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 2 of 15 took 189.676s
#   training loss:		0.663963
#   validation loss:		0.663433
#   validation accuracy:		64.94 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 3 of 15 took 190.320s
#   training loss:		0.652155
#   validation loss:		0.652111
#   validation accuracy:		66.02 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 4 of 15 took 190.063s
#   training loss:		0.638565
#   validation loss:		0.645698
#   validation accuracy:		64.84 %
# ...
# Epoch 14 of 15 took 20.880s
#   training loss:		0.479438
#   validation loss:		0.502591
#   validation accuracy:		74.83 %
#   normalised val acc:		0.75 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  Batch 43  Batch 44  Batch 45  Batch 46  Batch 47  Batch 48  Batch 49  Batch 50  Batch 51  Batch 52  Batch 53  Batch 54  Batch 55  Batch 56  Batch 57  Batch 58  Batch 59  Batch 60  Batch 61  Batch 62  Batch 63  Batch 64  Batch 65  Batch 66  Batch 67  Batch 68  Batch 69  Batch 70  Batch 71  Batch 72  Batch 73  Batch 74  Batch 75  Batch 76  Batch 77  Batch 78  Batch 79  Batch 80  Batch 81  Batch 82  Batch 83  Batch 84  Batch 85  Batch 86  (1184,) (1184,)
# Epoch 15 of 15 took 20.952s
#   training loss:		0.473086
#   validation loss:		0.527903
#   validation accuracy:		73.82 %
#   normalised val acc:		0.74 %
# normalised_accuracy: 0.738175675676
# elapsed: 319s
#
# run 19
# 0.0252070405068 1.0 5.0
# 75 19
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 1 of 15 took 71.428s
#   training loss:		0.695399
#   validation loss:		0.689996
#   validation accuracy:		49.51 %
#   normalised val acc:		0.50 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 2 of 15 took 69.729s
#   training loss:		0.690324
#   validation loss:		0.684968
#   validation accuracy:		50.00 %
#   normalised val acc:		0.50 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 3 of 15 took 68.921s
#   training loss:		0.686236
#   validation loss:		0.682440
#   validation accuracy:		52.83 %
#   normalised val acc:		0.53 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 4 of 15 took 71.370s
#   training loss:		0.680320
#   validation loss:		0.678568
#   validation accuracy:		53.91 %
#   normalised val acc:		0.54 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 5 of 15 took 69.942s
#   training loss:		0.677016
#   validation loss:		0.675236
#   validation accuracy:		56.84 %
#   normalised val acc:		0.57 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 6 of 15 took 71.489s
#   training loss:		0.672149
#   validation loss:		0.674280
#   validation accuracy:		60.74 %
#   normalised val acc:		0.61 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 7 of 15 took 70.084s
#   training loss:		0.671333
#   validation loss:		0.673221
#   validation accuracy:		64.65 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 8 of 15 took 69.525s
#   training loss:		0.666889
#   validation loss:		0.668309
#   validation accuracy:		66.89 %
#   normalised val acc:		0.67 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 9 of 15 took 68.923s
#   training loss:		0.665544
#   validation loss:		0.666417
#   validation accuracy:		66.21 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 10 of 15 took 69.962s
#   training loss:		0.660567
#   validation loss:		0.663609
#   validation accuracy:		66.31 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 11 of 15 took 69.619s
#   training loss:		0.658451
#   validation loss:		0.660227
#   validation accuracy:		67.58 %
#   normalised val acc:		0.68 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 12 of 15 took 69.145s
#   training loss:		0.656188
#   validation loss:		0.659544
#   validation accuracy:		66.41 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 13 of 15 took 70.833s
#   training loss:		0.652051
#   validation loss:		0.656711
#   validation accuracy:		67.38 %
#   normalised val acc:		0.67 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 14 of 15 took 69.721s
#   training loss:		0.650396
#   validation loss:		0.654960
#   validation accuracy:		66.31 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  (1024,) (1024,)
# Epoch 15 of 15 took 69.698s
#   training loss:		0.650572
#   validation loss:		0.653584
#   validation accuracy:		65.33 %
#   normalised val acc:		0.65 %
# normalised_accuracy: 0.6533203125
# elapsed: 1054s
#
# run 20
# 0.385719553641 1.0 5.0
# 75 19
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 1 of 15 took 111.693s
#   training loss:		0.683723
#   validation loss:		0.677574
#   validation accuracy:		67.27 %
#   normalised val acc:		0.67 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 2 of 15 took 114.236s
#   training loss:		0.663954
#   validation loss:		0.665431
#   validation accuracy:		63.02 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 3 of 15 took 114.918s
#   training loss:		0.646155
#   validation loss:		0.654754
#   validation accuracy:		63.37 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 4 of 15 took 114.890s
#   training loss:		0.634567
#   validation loss:		0.647304
#   validation accuracy:		62.85 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 5 of 15 took 114.980s
#   training loss:		0.626771
#   validation loss:		0.642697
#   validation accuracy:		63.28 %
#   normalised val acc:		0.63 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 6 of 15 took 115.631s
#   training loss:		0.616590
#   validation loss:		0.636085
#   validation accuracy:		63.63 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 7 of 15 took 114.852s
#   training loss:		0.612397
#   validation loss:		0.632556
#   validation accuracy:		64.06 %
#   normalised val acc:		0.64 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 8 of 15 took 115.354s
#   training loss:		0.608220
#   validation loss:		0.622156
#   validation accuracy:		65.19 %
#   normalised val acc:		0.65 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 9 of 15 took 115.180s
#   training loss:		0.595347
#   validation loss:		0.613549
#   validation accuracy:		66.15 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 10 of 15 took 113.890s
#   training loss:		0.588024
#   validation loss:		0.606117
#   validation accuracy:		66.49 %
#   normalised val acc:		0.66 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 11 of 15 took 114.710s
#   training loss:		0.579727
#   validation loss:		0.595919
#   validation accuracy:		67.45 %
#   normalised val acc:		0.67 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 12 of 15 took 114.781s
#   training loss:		0.569431
#   validation loss:		0.590390
#   validation accuracy:		67.88 %
#   normalised val acc:		0.68 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 13 of 15 took 114.270s
#   training loss:		0.560518
#   validation loss:		0.582445
#   validation accuracy:		68.32 %
#   normalised val acc:		0.68 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 14 of 15 took 114.693s
#   training loss:		0.552767
#   validation loss:		0.572391
#   validation accuracy:		69.36 %
#   normalised val acc:		0.69 %
# Batch 0  Batch 1  Batch 2  Batch 3  Batch 4  Batch 5  Batch 6  Batch 7  Batch 8  Batch 9  Batch 10  Batch 11  Batch 12  Batch 13  Batch 14  Batch 15  Batch 16  Batch 17  Batch 18  Batch 19  Batch 20  Batch 21  Batch 22  Batch 23  Batch 24  Batch 25  Batch 26  Batch 27  Batch 28  Batch 29  Batch 30  Batch 31  Batch 32  Batch 33  Batch 34  Batch 35  Batch 36  Batch 37  Batch 38  Batch 39  Batch 40  Batch 41  Batch 42  (1152,) (1152,)
# Epoch 15 of 15 took 114.096s
#   training loss:		0.546413
#   validation loss:		0.571058
#   validation accuracy:		69.01 %
#   normalised val acc:		0.69 %
# normalised_accuracy: 0.690104166667
# elapsed: 1722s
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-27-6670c3108b5b> in <module>()
#      47
#      48 start_time = time()
# ---> 49 best = fmin( run_wrapper, space, algo = tpe.suggest, max_evals = max_evals )
#      50 end_time = time()
#      51
#
# /home/michael/anaconda/lib/python2.7/site-packages/hyperopt/fmin.pyc in fmin(fn, space, algo, max_evals, trials, rseed)
#     332
#     333     rval = FMinIter(algo, domain, trials, max_evals=max_evals)
# --> 334     rval.exhaust()
#     335     return trials.argmin
#     336
#
# /home/michael/anaconda/lib/python2.7/site-packages/hyperopt/fmin.pyc in exhaust(self)
#     292     def exhaust(self):
#     293         n_done = len(self.trials)
# --> 294         self.run(self.max_evals - n_done, block_until_done=self.async)
#     295         self.trials.refresh()
#     296         return self
#
# /home/michael/anaconda/lib/python2.7/site-packages/hyperopt/fmin.pyc in run(self, N, block_until_done)
#     247                         print 'trial %i %s %s' % (d['tid'], d['state'],
#     248                             d['result'].get('status'))
# --> 249                 new_trials = algo(new_ids, self.domain, trials)
#     250                 if new_trials is base.StopExperiment:
#     251                     stopped = True
#
# /home/michael/anaconda/lib/python2.7/site-packages/hyperopt/tpe.pyc in suggest(new_ids, domain, trials, seed, prior_weight, n_startup_jobs, n_EI_candidates, gamma, linear_forgetting)
#     900
#     901     idxs, vals = pyll.rec_eval([opt_idxs, opt_vals], memo=memo,
# --> 902             print_node_on_error=False)
#     903
#     904     # -- retrieve the best of the samples and form the return tuple
#
# /home/michael/anaconda/lib/python2.7/site-packages/hyperopt/pyll/base.pyc in rec_eval(expr, deepcopy_inputs, memo, max_program_len, memo_gc, print_trace, print_node_on_error)
#     858
#     859             try:
# --> 860                 rval = scope._impls[node.name](*args, **kwargs)
#     861
#     862             except Exception, e:
#
# /home/michael/anaconda/lib/python2.7/site-packages/hyperopt/tpe.pyc in adaptive_parzen_normal(mus, prior_weight, prior_mu, prior_sigma, LF)
#     462
#     463     sigma[prior_pos] = prior_sigma
# --> 464     assert prior_sigma > 0
#     465     assert maxsigma > 0
#     466     assert minsigma > 0
#
# AssertionError:
