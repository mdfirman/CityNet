# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

from scipy.misc import imread, imsave
import cPickle as pickle
import yaml
import collections
from tqdm import tqdm
import time
from scipy.ndimage.interpolation import zoom

# %%
base = '/media/michael/Engage/data/audio/alison_data/golden_set/predictions/'

toload = ['overlap_ACI_noRound_baseline']
toload = ['overlap_BI_baseline']
# 'aci_baseline',

# %%
for load in toload:
    dirr = base + load + '/biotic/per_file_predictions/'
    for ff in os.listdir(dirr):

        fname = dirr + ff
        gt, res = pickle.load(open(fname))
        t = res[:, 0]
#         t -= t.min()
#         t /= t.max()
        plt.figure()
        plt.plot(t)    
        plt.plot(gt)
        plt.ylim(-0.1, 1.1)
        
    sds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-c2f42138a837> in <module>()
#      13         plt.ylim(-0.1, 1.1)
#      14
# ---> 15     sds
#
# NameError: name 'sds' is not defined
